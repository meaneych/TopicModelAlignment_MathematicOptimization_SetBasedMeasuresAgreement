# %%
########################
## A simple example of optimal alignment of lists, to maximize first/leading word alignment (from two fitted topic models).
##
## Author: Chris Meaney
## Date: December 2023
########################

# %%
## Dependencies
import gurobipy as gp
from gurobipy import GRB

import numpy as np
import pandas as pd

# %%
## Define "first-word alignment" loss function
def match_first_word_loss(a, b):
    return int(a[0]==b[0])

# %%
## Define some function to optimize semantic agreement - over arbitrary lists of elements A and B
## The function takes as inputs two lists of lists: A=[[],[],[]] and B=[[],[],[]] for example from two topic models
## The function returns the optimal alignment of the two lists/matrices using first word agreement objective function
def optimize_alignment(A, B):
    model = gp.Model("list_alignment")

    # Variables
    alignment_vars = {}
    for i in range(len(A)):
        for j in range(len(B)):
            alignment_vars[i, j] = model.addVar(vtype=GRB.BINARY, name=f"x_{i}_{j}")

    # Objective function
    obj_expr = gp.LinExpr()
    for i in range(len(A)):
        for j in range(len(B)):
            obj_expr += alignment_vars[i, j] * match_first_word_loss(A[i], B[j])

    model.setObjective(obj_expr, GRB.MAXIMIZE)

    # Constraints
    for i in range(len(A)):
        model.addConstr(gp.quicksum(alignment_vars[i, j] for j in range(len(B))) == 1)

    for j in range(len(B)):
        model.addConstr(gp.quicksum(alignment_vars[i, j] for i in range(len(A))) == 1)

    # Solve the model
    model.optimize()

    # Extract the solution
    alignment = []
    for i in range(len(A)):
        for j in range(len(B)):
            if alignment_vars[i, j].x == 1:
                alignment.append((A[i], B[j]))

    return alignment

# %%
## Import pandas dataFrame corresponding to two topical matrices 
file_dir = "C:\\Users\\ChristopherMeaney\\Desktop\\tmp\\pyGurobi_LinearAssignmentExample\\"

utopian_path = file_dir + "FINAL_UTOPIAN_TopicTable_NMF_K=50.csv"
emrpc_path = file_dir + "FINAL_EMRPC_TopicTable_NMF_K=50.csv"

utopian = pd.read_csv(utopian_path)
emrpc = pd.read_csv(emrpc_path)

# %%
## UTOPIAN topic table
utopian.iloc[:,1:6]
# Out:
#           word1         word2         word3         word4         word5
# 0       tylenol         advil           tab      headache          tabs
# 1            mg           tab          tabs      capsules            po
# 2         fever      diarrhea      vomiting  tylenoladvil         viral
# 3          neck          head           arm      headache     headaches
# 4            bw          iron           tsh      ferritin       thyroid
# 5          work        social        stress       working     treatment
# 6            bp      systolic     diastolic           htn       norvasc
# 7         sleep           bed      sleeping         apnea      insomnia
# 8       anxiety       anxious         panic        social   counselling
# 9           flu          shot  anaphylactic     influenza     ibuprofen
# 10       weight            kg           bmi        height           lbs
# 11         pain     palpation       flexion        physio           arm
# 12          ear       hearing          ears           wax       cerumen
# 13       eating          diet          food            wt         snack
# 14       throat          sore         strep         viral         nodes
# 15           rx      shingrix        ativan            ra           abx
# 16         meds           bmd           vit       chronic          bone
# 17          pap      bleeding       vaginal     discharge        pelvic
# 18      vaccine     influenza           flu       allergy         fever
# 19         dose    medication  immunization     injection      shingrix
# 20       breast        cancer        nipple     mammogram          lump
# 21  medications       allergy          drug      capsules       capsule
# 22        cough           sob      ventolin        asthma      coughing
# 23        bilat        masses         neuro         limbs          head
# 24        heart           bpm      systolic     diastolic            bp
# 25        urine           uti       urinary       dysuria     hematuria
# 26          eye        vision         drops          eyes     discharge
# 27     symptoms        nausea       urinary      headache            gi
# 28         foot      swelling         ankle           toe          feet
# 29           sx         neuro            gi       urinary        melena
# 30       mother        father       parents        sister       mothers
# 31         mood      cipralex    depression   counselling        speech
# 32     exercise          diet           ldl     screening        cancer
# 33      tablets        tablet   medications          oral            mg
# 34           rn  immunization     injection          baby           arm
# 35           er          felt          head            ct           sob
# 36        covid        health      physical     emergency      pandemic
# 37         back         spine        lumbar       flexion        physio
# 38          mom           dad       parents          baby       feeding
# 39        chest           sob           cvs         edema  palpitations
# 40         knee      swelling            oa         joint        medial
# 41        blood      pressure    medication         pulse        pounds
# 42       family        social   counselling       husband      daughter
# 43      feeling          felt         tired       anxious     treatment
# 44        feels          felt         tired        stress       anxious
# 45          hip          xray            oa        physio       flexion
# 46        nasal         sinus    congestion          nose       nasonex
# 47         skin          rash         cream          derm       lesions
# 48     referral          derm           ent            gi           mri
# 49         abdo      diarrhea         stool            bm        masses

# %%
## EMRPC topic table
emrpc.iloc[:,1:6]
# Out:
#            word1            word2       word3        word4          word5
# 0           pain          chronic     tylenol   gabapentin       percocet
# 1             ct             scan        head         wife     ultrasound
# 2            inr           dosage          mg          thx           wife
# 3            hip          tylenol        xray           oa         physio
# 4        insulin               dm      lantus     diabetes            fbs
# 5            flu             diet    exercise          ldl    medications
# 6             mg           tablet         qhs      tablets  hydromorphone
# 7        surgery         hospital     surgeon          eye      discharge
# 8             er          feeling    hospital    discharge       admitted
# 9          urine              uti    macrobid      culture            neg
# 10      pharmacy       pharmacist     blister  medications         script
# 11         feels          feeling        feel      husband        worried
# 12           lab             fear         ida          rpn             ml
# 13           son              ses     session           na      cognitive
# 14           prn           stable     tylenol        bilat             ed
# 15      coumadin              rpn        labs           mg            inr
# 16          abdo         diarrhea        soft        stool          fever
# 17          neck         headache        head     migraine         gravol
# 18           leg         swelling       edema         legs           calf
# 19          back           physio       spine         legs         lumbar
# 20         chest            clear         sob        heart          edema
# 21      referral             ccac      mental           sw            msg
# 22      warfarin  anticoagulation    bleeding          inr        student
# 23         blood         pressure     glucose     bleeding       diabetes
# 24           bid             tabs         tab     percocet         lyrica
# 25            rx               db       pharm         tabs            rxs
# 26            wt           weight         lbs           kg           loss
# 27          knee               oa    swelling         xray         medial
# 28           mri             head       spine          neg           xray
# 29            od               mg    diabetes      vitamin           labs
# 30       smoking        cessation        quit        patch          smoke
# 31      shoulder              arm      physio         cuff        rotator
# 32          mood          anxiety  depression      feeling         mental
# 33          meds              med      stable      chronic             oe
# 34      symptoms        treatment         uti      urinary         nausea
# 35            bp              tru         htn           wt        norvasc
# 36            bw               dm      stable          tsh           iron
# 37      daughter             ccac    hospital       family          house
# 38          dose           bloods         msg           db            thx
# 39          foot              toe        feet        ankle       swelling
# 40    medication             labs        wife  medications         dosage
# 41          work           stress         job         feel           sick
# 42     injection              arm     allergy           ml             lt
# 43          skin             rash      lesion       breast        lesions
# 44         sleep         sleeping         qhs     insomnia         asleep
# 45         cough           throat       fever         sore          clear
# 46         wound               cm        ccac    infection           head
# 47           ear             ears     hearing           rt            wax
# 48        social           worker      client          msw         mother
# 49  prescription               aa       pharm     percocet        patches

# %%
## Convert each of the above dataFrames into a list of list data structure
utopian_list = utopian.iloc[:, 1:6].values.tolist()
emrpc_list = emrpc.iloc[:, 1:6].values.tolist()

[len(utopian_list), len(emrpc_list)]
# Out:
# [50, 50]

# %%
# Optimize alignment between two topical summary matrices
alignment_result = optimize_alignment(utopian_list, emrpc_list)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-03-28
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i5-1035G1 CPU @ 1.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 100 rows, 2500 columns and 5000 nonzeros
# Model fingerprint: 0x7e2a5598
# Variable types: 0 continuous, 2500 integer (2500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective -0.0000000
# Presolve time: 0.05s
# Presolved: 100 rows, 2500 columns, 5000 nonzeros
# Variable types: 0 continuous, 2500 integer (2500 binary)
#
# Root relaxation: objective 2.700000e+01, 120 iterations, 0.02 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      27.0000000   27.00000  0.00%     -    0s
#
# Explored 1 nodes (120 simplex iterations) in 0.15 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 27 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.700000000000e+01, best bound 2.700000000000e+01, gap 0.0000%

# %%
# Print the result
# for a, b in alignment_result:
#    print(f"Align: {a} and {b}")
#    print("Match First Word Loss: ", int(a[0]==b[0]))
#    print('\n')

# %%
##
## Return the aligned lists as a pandas DataFrame
##
emrpc_list = []
utopian_list = []
intersection_list = []

# Print the result
for a, b in alignment_result:
    emrpc_list.append(b)
    utopian_list.append(a)
    intersection_list.append(a[0]==b[0])

res_df = pd.DataFrame({
    'emrpc': emrpc_list,
    'utopian': utopian_list,
    'intersection': intersection_list
})

res_df_ = res_df.sort_values('intersection', ascending=False)
res_df_
# Out:
#                                                 emrpc  \
# 25               [urine, uti, macrobid, culture, neg]
# 19                       [dose, bloods, msg, db, thx]
# 48                  [referral, ccac, mental, sw, msg]
# 47              [skin, rash, lesion, breast, lesions]
# 45                   [hip, tylenol, xray, oa, physio]
# 44           [feels, feeling, feel, husband, worried]
# 41     [blood, pressure, glucose, bleeding, diabetes]
# 40                 [knee, oa, swelling, xray, medial]
# 39                  [chest, clear, sob, heart, edema]
# 37                [back, physio, spine, legs, lumbar]
# 35       [er, feeling, hospital, discharge, admitted]
# 31       [mood, anxiety, depression, feeling, mental]
# 28                 [foot, toe, feet, ankle, swelling]
# 27        [symptoms, treatment, uti, urinary, nausea]
# 1           [mg, tablet, qhs, tablets, hydromorphone]
# 22                [cough, throat, fever, sore, clear]
# 49               [abdo, diarrhea, soft, stool, fever]
# 9             [flu, diet, exercise, ldl, medications]
# 6                         [bp, tru, htn, wt, norvasc]
# 16                   [meds, med, stable, chronic, oe]
# 3            [neck, headache, head, migraine, gravol]
# 15                         [rx, db, pharm, tabs, rxs]
# 4                         [bw, dm, stable, tsh, iron]
# 5                     [work, stress, job, feel, sick]
# 11     [pain, chronic, tylenol, gabapentin, percocet]
# 7            [sleep, sleeping, qhs, insomnia, asleep]
# 12                      [ear, ears, hearing, rt, wax]
# 38                 [son, ses, session, na, cognitive]
# 8                [insulin, dm, lantus, diabetes, fbs]
# 17           [smoking, cessation, quit, patch, smoke]
# 42                       [inr, dosage, mg, thx, wife]
# 36                        [wt, weight, lbs, kg, loss]
# 46          [daughter, ccac, hospital, family, house]
# 2                  [ct, scan, head, wife, ultrasound]
# 43                     [coumadin, rpn, labs, mg, inr]
# 33       [prescription, aa, pharm, percocet, patches]
# 10  [warfarin, anticoagulation, bleeding, inr, stu...
# 34                  [od, mg, diabetes, vitamin, labs]
# 18                      [mri, head, spine, neg, xray]
# 32             [shoulder, arm, physio, cuff, rotator]
# 30       [surgery, hospital, surgeon, eye, discharge]
# 29                          [lab, fear, ida, rpn, ml]
# 13                 [leg, swelling, edema, legs, calf]
# 26                  [injection, arm, allergy, ml, lt]
# 14                 [bid, tabs, tab, percocet, lyrica]
# 24      [medication, labs, wife, medications, dosage]
# 23                  [prn, stable, tylenol, bilat, ed]
# 21              [social, worker, client, msw, mother]
# 20  [pharmacy, pharmacist, blister, medications, s...
# 0                  [wound, cm, ccac, infection, head]
#
#                                               utopian  intersection
# 25          [urine, uti, urinary, dysuria, hematuria]          True
# 19  [dose, medication, immunization, injection, sh...          True
# 48                     [referral, derm, ent, gi, mri]          True
# 47                 [skin, rash, cream, derm, lesions]          True
# 45                   [hip, xray, oa, physio, flexion]          True
# 44              [feels, felt, tired, stress, anxious]          True
# 41       [blood, pressure, medication, pulse, pounds]          True
# 40                [knee, swelling, oa, joint, medial]          True
# 39             [chest, sob, cvs, edema, palpitations]          True
# 37             [back, spine, lumbar, flexion, physio]          True
# 35                          [er, felt, head, ct, sob]          True
# 31  [mood, cipralex, depression, counselling, speech]          True
# 28                 [foot, swelling, ankle, toe, feet]          True
# 27          [symptoms, nausea, urinary, headache, gi]          True
# 1                       [mg, tab, tabs, capsules, po]          True
# 22           [cough, sob, ventolin, asthma, coughing]          True
# 49                [abdo, diarrhea, stool, bm, masses]          True
# 9     [flu, shot, anaphylactic, influenza, ibuprofen]          True
# 6             [bp, systolic, diastolic, htn, norvasc]          True
# 16                    [meds, bmd, vit, chronic, bone]          True
# 3              [neck, head, arm, headache, headaches]          True
# 15                    [rx, shingrix, ativan, ra, abx]          True
# 4                  [bw, iron, tsh, ferritin, thyroid]          True
# 5          [work, social, stress, working, treatment]          True
# 11            [pain, palpation, flexion, physio, arm]          True
# 7             [sleep, bed, sleeping, apnea, insomnia]          True
# 12                 [ear, hearing, ears, wax, cerumen]          True
# 38                 [mom, dad, parents, baby, feeding]         False
# 8      [anxiety, anxious, panic, social, counselling]         False
# 17        [pap, bleeding, vaginal, discharge, pelvic]         False
# 42   [family, social, counselling, husband, daughter]         False
# 36     [covid, health, physical, emergency, pandemic]         False
# 46          [nasal, sinus, congestion, nose, nasonex]         False
# 2    [fever, diarrhea, vomiting, tylenoladvil, viral]         False
# 43         [feeling, felt, tired, anxious, treatment]         False
# 33           [tablets, tablet, medications, oral, mg]         False
# 10                     [weight, kg, bmi, height, lbs]         False
# 34           [rn, immunization, injection, baby, arm]         False
# 18          [vaccine, influenza, flu, allergy, fever]         False
# 32           [exercise, diet, ldl, screening, cancer]         False
# 30         [mother, father, parents, sister, mothers]         False
# 29                   [sx, neuro, gi, urinary, melena]         False
# 13                    [eating, diet, food, wt, snack]         False
# 26              [eye, vision, drops, eyes, discharge]         False
# 14                [throat, sore, strep, viral, nodes]         False
# 24              [heart, bpm, systolic, diastolic, bp]         False
# 23                [bilat, masses, neuro, limbs, head]         False
# 21    [medications, allergy, drug, capsules, capsule]         False
# 20          [breast, cancer, nipple, mammogram, lump]         False
# 0               [tylenol, advil, tab, headache, tabs]         False

# %%
##
## Compute objective function
##
res_df_.intersection.sum()
# Out:
# 27

# %%
## Note: for the 33 topical vectors where first words DO NOT match, the alignment/solution is arbitrary
## i.e. there exist several other solutions where one permutes the topical vectors without matching first word/token

# %%
##########################
## Write solution to disk
##########################

# %%
out_path = "C:\\Users\\ChristopherMeaney\\Desktop\\tmp\\pyGurobi_LinearAssignmentExample\\MILP_Solver_MatchFirstWordObjective.csv"
res_df_.to_csv(path_or_buf=out_path, sep=',', index=False)

# %%
#######################################
## Properties of noteboook
#######################################

# %%
## Notebook last run on following date
from datetime import date
print(date.today())
# Out:
# 2023-12-27

# %%
## Session information
# !pip install session_info
import session_info
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# gurobipy            NA
# numpy               1.26.0
# pandas              2.1.1
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# anyio                       NA
# asttokens                   NA
# attr                        23.1.0
# attrs                       23.1.0
# babel                       2.11.0
# backcall                    0.2.0
# bottleneck                  1.3.5
# brotli                      1.0.9
# certifi                     2023.11.17
# charset_normalizer          2.0.4
# colorama                    0.4.6
# comm                        0.1.2
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.6.7
# decorator                   5.1.1
# executing                   0.8.3
# fastjsonschema              NA
# idna                        3.4
# ipykernel                   6.25.0
# jedi                        0.18.1
# jinja2                      3.1.2
# json5                       NA
# jsonschema                  4.19.2
# jsonschema_specifications   NA
# jupyter_events              0.8.0
# jupyter_server              2.10.0
# jupyterlab_server           2.25.1
# markupsafe                  2.1.1
# mkl                         2.4.0
# nbformat                    5.9.2
# numexpr                     2.8.7
# overrides                   NA
# packaging                   23.1
# parso                       0.8.3
# pickleshare                 0.7.5
# pkg_resources               NA
# platformdirs                3.10.0
# prometheus_client           NA
# prompt_toolkit              3.0.36
# psutil                      5.9.0
# pure_eval                   0.2.2
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.15.1
# pythoncom                   NA
# pythonjsonlogger            NA
# pytz                        2023.3.post1
# pywin32_system32            NA
# pywintypes                  NA
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# send2trash                  NA
# six                         1.16.0
# sniffio                     1.2.0
# socks                       1.7.1
# stack_data                  0.2.0
# tornado                     6.3.3
# traitlets                   5.7.1
# urllib3                     1.26.18
# wcwidth                     0.2.5
# websocket                   0.58.0
# win32api                    NA
# win32com                    NA
# win32con                    NA
# win32trace                  NA
# winerror                    NA
# yaml                        6.0.1
# zmq                         25.1.0
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.15.0
# jupyter_client      8.6.0
# jupyter_core        5.5.0
# jupyterlab          4.0.8
# notebook            7.0.6
# -----
# Python 3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]
# Windows-10-10.0.22621-SP0
# -----
# Session information updated at 2023-12-27 09:56
# </pre>
# </details>
